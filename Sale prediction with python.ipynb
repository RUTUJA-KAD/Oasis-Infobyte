# %% [markdown]
# <h3> Oasis Infobyte Internship</h3>
# <h3> Intern - Rutuja Kad</h3>
# <h3> Domain - Data Science</h3>
# <h3> Task - 5</h3>
# <h3> Task - Sale prediction with python</h3>

# %% [markdown]
# # # importing the libraries for data analysis

# %%
# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Command to tell Python to actually display the graphs
# %matplotlib inline

# %%
sale=pd.read_csv(r"C:\Users\Rutu\Downloads\Advertising.csv", 
               encoding="ISO-8859-1")

# %%
sale
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
sale.shape
# Out:
# (200, 5)

# %%
sale.size
# Out:
# 1000

# %%
sale.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
sale.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
sale.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
sale.duplicated().sum()
# Out:
# 0

# %%
#rename the column name 
sale = sale.rename(columns = {'Unnamed: 0':'mobile'})

# %%
sale.head()
# Out:
#    mobile     TV  Radio  Newspaper  Sales
# 0       1  230.1   37.8       69.2   22.1
# 1       2   44.5   39.3       45.1   10.4
# 2       3   17.2   45.9       69.3    9.3
# 3       4  151.5   41.3       58.5   18.5
# 4       5  180.8   10.8       58.4   12.9

# %%
sale.describe()
# Out:
#            mobile          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# <h3>Visualisation </h3>

# %%
sns.pairplot(sale[['TV','Radio','Newspaper','Sales']])
# Out:
# C:\Users\Rutu\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sale.corr()
# Out:
#              mobile        TV     Radio  Newspaper     Sales
# mobile     1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV         0.017715  1.000000  0.054809   0.056648  0.782224
# Radio     -0.110680  0.054809  1.000000   0.354104  0.576223
# Newspaper -0.154944  0.056648  0.354104   1.000000  0.228299
# Sales     -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
sns.heatmap(sale.corr(), annot = True, cmap = 'Reds')
# Out:
# <Axes: >

# %%
y = sale['Sales']#Dependent variable and target
x = sale.drop(columns=['Sales']) 
# input and independent data

# %%
x
# Out:
#      mobile     TV  Radio  Newspaper
# 0         1  230.1   37.8       69.2
# 1         2   44.5   39.3       45.1
# 2         3   17.2   45.9       69.3
# 3         4  151.5   41.3       58.5
# 4         5  180.8   10.8       58.4
# ..      ...    ...    ...        ...
# 195     196   38.2    3.7       13.8
# 196     197   94.2    4.9        8.1
# 197     198  177.0    9.3        6.4
# 198     199  283.6   42.0       66.2
# 199     200  232.1    8.6        8.7
#
# [200 rows x 4 columns]

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
## Feature Importance

from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(x,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [0.00553956 0.61458438 0.37261609 0.00725998]

# %%
## plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=x.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state = 5)
regressor = LinearRegression()

#fit the model
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_train.shape
# Out:
# (160, 4)

# %%
x_train
# Out:
#      mobile     TV  Radio  Newspaper
# 159     160  131.7   18.4       34.6
# 62       63  239.3   15.5       27.3
# 166     167   17.9   37.6       21.6
# 45       46  175.1   22.5       31.5
# 23       24  228.3   16.9       26.2
# ..      ...    ...    ...        ...
# 73       74  129.4    5.7       31.3
# 144     145   96.2   14.8       38.9
# 118     119  125.7   36.9       79.2
# 189     190   18.7   12.1       23.4
# 99      100  135.2   41.7       45.9
#
# [160 rows x 4 columns]

# %%
x_test.shape
# Out:
# (40, 4)

# %%
x_test
# Out:
#      mobile     TV  Radio  Newspaper
# 119     120   19.4   16.0       22.3
# 77       78  120.5   28.5       14.2
# 148     149   38.0   40.3       11.9
# 149     150   44.7   25.8       20.6
# 154     155  187.8   21.1        9.5
# 151     152  121.0    8.4       48.7
# 122     123  224.0    2.4       15.6
# 6         7   57.5   32.8       23.5
# 28       29  248.8   27.1       22.9
# 71       72  109.8   14.3       31.7
# 188     189  286.0   13.9        3.7
# 34       35   95.7    1.4        7.4
# 21       22  237.4    5.1       23.5
# 40       41  202.5   22.3       31.6
# 55       56  198.9   49.4       60.0
# 104     105  238.2   34.3        5.3
# 3         4  151.5   41.3       58.5
# 39       40  228.0   37.7       32.0
# 117     118   76.4    0.8       14.8
# 134     135   36.9   38.6       65.6
# 180     181  156.6    2.6        8.3
# 26       27  142.9   29.3       12.6
# 54       55  262.7   28.8       15.9
# 165     166  234.5    3.4       84.8
# ...

# %%
y_train.shape
# Out:
# (160,)

# %%
y_train
# Out:
# 159    12.9
# 62     15.7
# 166     8.0
# 45     14.9
# 23     15.5
#        ...
# 73     11.0
# 144    11.4
# 118    15.9
# 189     6.7
# 99     17.2
# Name: Sales, Length: 160, dtype: float64

# %%
y_test.shape
# Out:
# (40,)

# %%
y_test
# Out:
# 119     6.6
# 77     14.2
# 148    10.9
# 149    10.1
# 154    15.6
# 151    11.6
# 122    11.6
# 6      11.8
# 28     18.9
# 71     12.4
# 188    15.9
# 34      9.5
# 21     12.5
# 40     16.6
# 55     23.7
# 104    20.7
# 3      18.5
# 39     21.5
# 117     9.4
# 134    10.8
# 180    10.5
# 26     15.0
# 54     20.2
# 165    11.9
# 53     21.2
# 93     22.2
# 174    11.5
# 17     24.4
# 56      5.5
# 84     21.7
# 25     12.0
# 156    15.3
# 42     20.7
# 141    19.2
# 50     11.4
# 51     10.7
# 195     7.6
# 116    12.2
# 142    20.1
# 24      9.7
# Name: Sales, dtype: float64

# %%
ypred = regressor.predict(x_test)

# %%
ypred
# Out:
# array([ 6.7174225 , 13.76558541, 12.03227762,  9.68569193, 15.55770425,
#        10.03895883, 13.84283215, 11.59963733, 19.52577715, 10.64397635,
#        18.85001714,  7.68425957, 14.9792417 , 16.45978357, 21.17868616,
#        20.35126044, 17.49631778, 20.46424114,  6.63201782, 11.57824485,
#        10.71456985, 14.97985562, 20.49265172, 14.38067791, 19.83350779,
#        21.23099576, 13.93940234, 23.27877629,  8.34128574, 20.73452345,
#        15.88925681, 15.16576745, 21.76995907, 18.32784551, 12.82266642,
#         9.40221645,  5.34841596, 12.0204495 , 19.25080988,  8.14421627])

# %%
sale.Sales.plot()
# Out:
# <Axes: >

# %%
train_data_prediction= regressor.predict(x_train)

# %%
from sklearn import metrics
error_score = metrics.r2_score(y_train, train_data_prediction)
print('R squared error:',error_score)
# Out:
# R squared error: 0.89570620107301

# %%
print('R squared training set :', round(regressor.score(x_test,y_test)))
# Out:
# R squared training set : 1

# %%
print('R squared test set : ',round(regressor.score(x_train,y_train)*1))
# Out:
# R squared test set :  1

# %%
regressor.coef_
# Out:
# array([-0.00029408,  0.04689617,  0.18240453, -0.00179658])

# %%
plt.scatter(y_train,train_data_prediction)
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title('Actual Sales vs Predicted Sales')
plt.show()

# %%
test_data_prediction = regressor.predict(x_test)

# %%
from sklearn import metrics
error_score = metrics.r2_score(y_test, test_data_prediction)
print('R squared error:',error_score)
# Out:
# R squared error: 0.89851958363058

# %%
print('R squared training set : ',round(regressor.score(x_test,y_test)))
# Out:
# R squared training set :  1

# %%
print('R squared test set : ',round(regressor.score(x_train,y_train)))
# Out:
# R squared test set :  1

# %%
plt.scatter(y_test,test_data_prediction)
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title('Actual Sales vs Predicted Sales')
plt.show()

# %%
ypred
# Out:
# array([ 6.7174225 , 13.76558541, 12.03227762,  9.68569193, 15.55770425,
#        10.03895883, 13.84283215, 11.59963733, 19.52577715, 10.64397635,
#        18.85001714,  7.68425957, 14.9792417 , 16.45978357, 21.17868616,
#        20.35126044, 17.49631778, 20.46424114,  6.63201782, 11.57824485,
#        10.71456985, 14.97985562, 20.49265172, 14.38067791, 19.83350779,
#        21.23099576, 13.93940234, 23.27877629,  8.34128574, 20.73452345,
#        15.88925681, 15.16576745, 21.76995907, 18.32784551, 12.82266642,
#         9.40221645,  5.34841596, 12.0204495 , 19.25080988,  8.14421627])
