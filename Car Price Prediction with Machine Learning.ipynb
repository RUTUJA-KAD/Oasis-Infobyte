# %% [markdown]
# <h3> Oasis Infobyte Internship</h3>
# <h3> Intern - Rutuja Kad</h3>
# <h3> Domain - Data Science</h3>
# <h3> Task - 3</h3>
# <h3> Task - Car Price Prediction with Machine Learning</h3>

# %% [markdown]
# # # importing the libraries for data analysis

# %%
# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Command to tell Python to actually display the graphs
# %matplotlib inline

# %% [markdown]
# <h1>#importing dataset</h1>

# %%
car=pd.read_csv(r"C:\Users\Rutu\Downloads\car data.csv", 
               encoding="ISO-8859-1")

# %%
car
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# 2         Dealer       Manual      0
# 3         Dealer       Manual      0
# 4         Dealer       Manual      0
# ..           ...          ...    ...
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
car.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
car.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Selling_type Transmission  Owner
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
car.describe()
# Out:
#               Year  Selling_Price  Present_Price     Driven_kms       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.642584   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
car.shape
# Out:
# (301, 9)

# %%
car.size
# Out:
# 2709

# %%
car.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
#remove duplicate
car= car.drop_duplicates()

# %%
car.duplicated().sum()
# Out:
# 0

# %%
car.shape
# Out:
# (299, 9)

# %%
car['Year'].unique()
# Out:
# array([2014, 2013, 2017, 2011, 2018, 2015, 2016, 2009, 2010, 2012, 2003,
#        2008, 2006, 2005, 2004, 2007], dtype=int64)

# %%
car['Year'].nunique()
# Out:
# 16

# %%
car = car.drop(columns = 'Car_Name')

# %%
#Adding Column name age of car
car['current year']=2023

# %%
car
# Out:
#      Year  Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0    2014           3.35           5.59       27000    Petrol       Dealer
# 1    2013           4.75           9.54       43000    Diesel       Dealer
# 2    2017           7.25           9.85        6900    Petrol       Dealer
# 3    2011           2.85           4.15        5200    Petrol       Dealer
# 4    2014           4.60           6.87       42450    Diesel       Dealer
# ..    ...            ...            ...         ...       ...          ...
# 296  2016           9.50          11.60       33988    Diesel       Dealer
# 297  2015           4.00           5.90       60000    Petrol       Dealer
# 298  2009           3.35          11.00       87934    Petrol       Dealer
# 299  2017          11.50          12.50        9000    Diesel       Dealer
# 300  2016           5.30           5.90        5464    Petrol       Dealer
#
#     Transmission  Owner  current year
# 0         Manual      0          2023
# 1         Manual      0          2023
# 2         Manual      0          2023
# 3         Manual      0          2023
# 4         Manual      0          2023
# ..           ...    ...           ...
# 296       Manual      0          2023
# 297       Manual      0          2023
# 298       Manual      0          2023
# 299       Manual      0          2023
# 300       Manual      0          2023
#
# [299 rows x 9 columns]

# %%
car['Age of Car']= car['current year']-car['Year']

# %%
car
# Out:
#      Year  Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0    2014           3.35           5.59       27000    Petrol       Dealer
# 1    2013           4.75           9.54       43000    Diesel       Dealer
# 2    2017           7.25           9.85        6900    Petrol       Dealer
# 3    2011           2.85           4.15        5200    Petrol       Dealer
# 4    2014           4.60           6.87       42450    Diesel       Dealer
# ..    ...            ...            ...         ...       ...          ...
# 296  2016           9.50          11.60       33988    Diesel       Dealer
# 297  2015           4.00           5.90       60000    Petrol       Dealer
# 298  2009           3.35          11.00       87934    Petrol       Dealer
# 299  2017          11.50          12.50        9000    Diesel       Dealer
# 300  2016           5.30           5.90        5464    Petrol       Dealer
#
#     Transmission  Owner  current year  Age of Car
# 0         Manual      0          2023           9
# 1         Manual      0          2023          10
# 2         Manual      0          2023           6
# 3         Manual      0          2023          12
# 4         Manual      0          2023           9
# ..           ...    ...           ...         ...
# 296       Manual      0          2023           7
# 297       Manual      0          2023           8
# 298       Manual      0          2023          14
# 299       Manual      0          2023           6
# 300       Manual      0          2023           7
#
# [299 rows x 10 columns]

# %%
car = car.drop(columns=['current year', 'Year'])
car
# Out:
#      Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0             3.35           5.59       27000    Petrol       Dealer
# 1             4.75           9.54       43000    Diesel       Dealer
# 2             7.25           9.85        6900    Petrol       Dealer
# 3             2.85           4.15        5200    Petrol       Dealer
# 4             4.60           6.87       42450    Diesel       Dealer
# ..             ...            ...         ...       ...          ...
# 296           9.50          11.60       33988    Diesel       Dealer
# 297           4.00           5.90       60000    Petrol       Dealer
# 298           3.35          11.00       87934    Petrol       Dealer
# 299          11.50          12.50        9000    Diesel       Dealer
# 300           5.30           5.90        5464    Petrol       Dealer
#
#     Transmission  Owner  Age of Car
# 0         Manual      0           9
# 1         Manual      0          10
# 2         Manual      0           6
# 3         Manual      0          12
# 4         Manual      0           9
# ..           ...    ...         ...
# 296       Manual      0           7
# 297       Manual      0           8
# 298       Manual      0          14
# 299       Manual      0           6
# 300       Manual      0           7
#
# [299 rows x 8 columns]

# %%
car.Owner.value_counts()
# Out:
# Owner
# 0    288
# 1     10
# 3      1
# Name: count, dtype: int64

# %% [markdown]
# <h1>Encoding</h1>

# %%
car = pd.get_dummies(data=car, drop_first = True)

# %%
car
# Out:
#      Selling_Price  Present_Price  Driven_kms  Owner  Age of Car  \
# 0             3.35           5.59       27000      0           9
# 1             4.75           9.54       43000      0          10
# 2             7.25           9.85        6900      0           6
# 3             2.85           4.15        5200      0          12
# 4             4.60           6.87       42450      0           9
# ..             ...            ...         ...    ...         ...
# 296           9.50          11.60       33988      0           7
# 297           4.00           5.90       60000      0           8
# 298           3.35          11.00       87934      0          14
# 299          11.50          12.50        9000      0           6
# 300           5.30           5.90        5464      0           7
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Selling_type_Individual  \
# 0               False              True                    False
# 1                True             False                    False
# 2               False              True                    False
# 3               False              True                    False
# 4                True             False                    False
# ..                ...               ...                      ...
# 296              True             False                    False
# 297             False              True                    False
# 298             False              True                    False
# 299              True             False                    False
# 300             False              True                    False
#
#      Transmission_Manual
# 0                   True
# 1                   True
# 2                   True
# 3                   True
# 4                   True
# ..                   ...
# 296                 True
# 297                 True
# 298                 True
# 299                 True
# 300                 True
#
# [299 rows x 9 columns]

# %%
g=['Fuel_Type_Diesel','Fuel_Type_Petrol','Selling_type_Individual','Transmission_Manual']
car[g] = car[g].astype('int')

# %%
car.head(5)
# Out:
#    Selling_Price  Present_Price  Driven_kms  Owner  Age of Car  \
# 0           3.35           5.59       27000      0           9
# 1           4.75           9.54       43000      0          10
# 2           7.25           9.85        6900      0           6
# 3           2.85           4.15        5200      0          12
# 4           4.60           6.87       42450      0           9
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Selling_type_Individual  \
# 0                 0                 1                        0
# 1                 1                 0                        0
# 2                 0                 1                        0
# 3                 0                 1                        0
# 4                 1                 0                        0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
car.corr()
# Out:
#                          Selling_Price  Present_Price  Driven_kms     Owner  \
# Selling_Price                 1.000000       0.876305    0.028566 -0.087880
# Present_Price                 0.876305       1.000000    0.205224  0.009948
# Driven_kms                    0.028566       0.205224    1.000000  0.089367
# Owner                        -0.087880       0.009948    0.089367  1.000000
# Age of Car                   -0.234369       0.053167    0.525714  0.181639
# Fuel_Type_Diesel              0.543541       0.464934    0.173295 -0.051836
# Fuel_Type_Petrol             -0.531636      -0.456829   -0.173595  0.054102
# Selling_type_Individual      -0.553851      -0.511779   -0.101030  0.123646
# Transmission_Manual          -0.348869      -0.334326   -0.163881 -0.052166
#
#                          Age of Car  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price             -0.234369          0.543541         -0.531636
# Present_Price              0.053167          0.464934         -0.456829
# Driven_kms                 0.525714          0.173295         -0.173595
# Owner                      0.181639         -0.051836          0.054102
# Age of Car                 1.000000         -0.056469          0.052197
# Fuel_Type_Diesel          -0.056469          1.000000         -0.979104
# Fuel_Type_Petrol           0.052197         -0.979104          1.000000
# Selling_type_Individual    0.036820         -0.345882          0.353865
# Transmission_Manual       -0.003434         -0.086264          0.078700
#
#                          Selling_type_Individual  Transmission_Manual
# Selling_Price                          -0.553851            -0.348869
# Present_Price                          -0.511779            -0.334326
# Driven_kms                             -0.101030            -0.163881
# Owner                                   0.123646            -0.052166
# Age of Car                              0.036820            -0.003434
# Fuel_Type_Diesel                       -0.345882            -0.086264
# Fuel_Type_Petrol                        0.353865             0.078700
# Selling_type_Individual                 1.000000             0.058669
# Transmission_Manual                     0.058669             1.000000

# %%
import warnings

# %%
warnings.filterwarnings('ignore')
sns.pairplot(car)

# %%
sns.heatmap(car.corr(), annot = True, cmap = 'Reds')
# Out:
# <Axes: >

# %%
#splitting of data

# %%
y = car['Selling_Price']#Dependent variable and target
x = car.drop(columns=['Selling_Price']) 
# input and independent data

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 299, dtype: float64

# %%
x
# Out:
#      Present_Price  Driven_kms  Owner  Age of Car  Fuel_Type_Diesel  \
# 0             5.59       27000      0           9                 0
# 1             9.54       43000      0          10                 1
# 2             9.85        6900      0           6                 0
# 3             4.15        5200      0          12                 0
# 4             6.87       42450      0           9                 1
# ..             ...         ...    ...         ...               ...
# 296          11.60       33988      0           7                 1
# 297           5.90       60000      0           8                 0
# 298          11.00       87934      0          14                 0
# 299          12.50        9000      0           6                 1
# 300           5.90        5464      0           7                 0
#
#      Fuel_Type_Petrol  Selling_type_Individual  Transmission_Manual
# 0                   1                        0                    1
# 1                   0                        0                    1
# 2                   1                        0                    1
# 3                   1                        0                    1
# 4                   0                        0                    1
# ..                ...                      ...                  ...
# 296                 0                        0                    1
# 297                 1                        0                    1
# 298                 1                        0                    1
# 299                 0                        0                    1
# 300                 1                        0                    1
#
# [299 rows x 8 columns]

# %%
## Feature Importance

from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(x,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(model.feature_importances_)
#
# NameError: name 'model' is not defined

# %%
## plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=x.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.show()

# %%
## BUILDING MODEL

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state = 5)
regressor = LinearRegression()

#fit the model
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_train
# Out:
#      Present_Price  Driven_kms  Owner  Age of Car  Fuel_Type_Diesel  \
# 239           4.43       23709      0          11                 0
# 22            8.01       50000      0          12                 0
# 43            8.06       45780      0           9                 1
# 183           0.47       21000      0          10                 0
# 100           1.90        3000      0           7                 0
# ..             ...         ...    ...         ...               ...
# 8             8.89       20273      0           7                 1
# 74            8.93       83000      0           9                 1
# 120           1.26        5700      0           7                 0
# 191           0.57       25000      1          11                 0
# 208           8.10        3435      0           6                 0
#
#      Fuel_Type_Petrol  Selling_type_Individual  Transmission_Manual
# 239                 1                        0                    1
# 22                  1                        0                    0
# 43                  0                        0                    1
# 183                 1                        1                    1
# 100                 1                        1                    1
# ..                ...                      ...                  ...
# 8                   0                        0                    1
# 74                  0                        0                    1
# 120                 1                        1                    1
# 191                 1                        1                    1
# 208                 1                        0                    1
#
# [239 rows x 8 columns]

# %%
y_train
# Out:
# 239    2.00
# 22     4.40
# 43     5.50
# 183    0.27
# 100    1.75
#        ...
# 8      8.75
# 74     4.90
# 120    1.05
# 191    0.20
# 208    7.90
# Name: Selling_Price, Length: 239, dtype: float64

# %%
x_test
# Out:
#      Present_Price  Driven_kms  Owner  Age of Car  Fuel_Type_Diesel  \
# 200          0.750       92233      0          17                 0
# 67          20.450       59000      0          13                 1
# 25           4.990       20000      0          12                 0
# 104          1.470        4100      0           6                 0
# 266          7.000       35000      0           9                 0
# 50          30.610      104707      0          11                 1
# 262          5.800       40023      0           8                 0
# 161          0.826       23000      0           9                 0
# 97          18.640        8700      0           6                 0
# 119          1.900        5400      0          10                 0
# 217          4.430       15000      0           7                 0
# 180          0.510       60000      0          11                 0
# 63          35.960       47000      0           8                 1
# 255          5.350       53675      0          11                 0
# 44           2.690       50000      0          11                 0
# 227          4.430       57000      0          12                 0
# 274          6.800       16500      0           9                 0
# 51          30.610       40000      0           8                 1
# 235          9.400       15141      0           6                 0
# 265          8.700       21200      0           6                 0
# 223          9.400       61381      0           8                 1
# 117          1.900       14000      0           8                 0
# 289         13.600       10980      0           7                 0
# 293          9.900       38000      0          13                 0
# 141          0.800       20000      0           7                 0
# 287          7.500       44000      0           8                 0
# 246          6.790       35000      0          11                 0
# 62          35.960       78000      0           9                 1
# 211         14.790       43535      0           8                 1
# 187          0.510       32000      0          10                 0
# 91          16.090       58242      0           9                 1
# 121          1.500        6900      0          12                 0
# 248          4.600       30000      0          10                 0
# 203          4.600       53460      0          12                 0
# 270         10.000       69341      0          12                 0
# 252          6.820       31427      0           8                 0
# 259          7.000       36054      0           9                 0
# 197          0.510       33000      0          13                 0
# 215          9.400       36100      0          11                 0
# 173          0.510        1300      0           6                 0
# 40           7.870       24524      0           7                 0
# 282         14.000       63000      0           9                 1
# 69          20.910       12000      0           7                 0
# 26           5.870       55138      0          10                 0
# 61           7.700       40588      0           8                 0
# 125          1.750       40000      0          14                 0
# 101          1.820        1400      0           6                 0
# 95          18.610       72000      0          11                 0
# 234          5.700        4492      0           8                 0
# 257         13.600       40324      0           8                 0
# 291          6.100       31427      0           8                 0
# 85          23.730      142000      3          17                 0
# 57          18.540       50000      0          13                 0
# 231          9.400       15001      0           6                 0
# 136          1.200       23500      0           9                 0
# 108          1.500       18000      0           7                 0
# 273          7.500       61203      0          13                 0
# 49           9.290       37000      0           6                 0
# 225          4.600       22517      0          12                 0
# 170          0.830        5500      0          11                 0
#
#      Fuel_Type_Petrol  Selling_type_Individual  Transmission_Manual
# 200                 1                        1                    1
# 67                  0                        0                    1
# 25                  1                        0                    1
# 104                 1                        1                    1
# 266                 1                        0                    1
# 50                  0                        0                    0
# 262                 1                        0                    1
# 161                 1                        1                    1
# 97                  1                        0                    1
# 119                 1                        1                    1
# 217                 1                        0                    1
# 180                 1                        1                    1
# 63                  0                        0                    0
# 255                 1                        0                    1
# 44                  1                        0                    1
# 227                 1                        0                    1
# 274                 1                        0                    1
# 51                  0                        0                    0
# 235                 1                        0                    1
# 265                 1                        0                    1
# 223                 0                        0                    1
# 117                 1                        1                    1
# 289                 1                        0                    1
# 293                 1                        0                    1
# 141                 1                        1                    1
# 287                 1                        0                    0
# 246                 1                        0                    1
# 62                  0                        0                    0
# 211                 0                        0                    1
# 187                 1                        1                    1
# 91                  0                        0                    1
# 121                 1                        1                    1
# 248                 1                        0                    1
# 203                 1                        0                    1
# 270                 1                        0                    1
# 252                 1                        0                    0
# 259                 1                        0                    1
# 197                 1                        1                    1
# 215                 1                        0                    1
# 173                 1                        1                    0
# 40                  1                        0                    0
# 282                 0                        0                    1
# 69                  1                        0                    1
# 26                  1                        0                    1
# 61                  1                        0                    1
# 125                 1                        1                    1
# 101                 1                        1                    1
# 95                  1                        0                    1
# 234                 1                        0                    1
# 257                 1                        0                    1
# 291                 1                        0                    1
# 85                  1                        1                    0
# 57                  1                        0                    1
# 231                 1                        0                    1
# 136                 1                        1                    1
# 108                 1                        1                    1
# 273                 1                        0                    1
# 49                  1                        0                    0
# 225                 1                        0                    1
# 170                 1                        1                    1

# %%
y_test
# Out:
# 200     0.10
# 67      9.25
# 25      3.00
# 104     1.35
# 266     3.65
# 50     14.90
# 262     4.00
# 161     0.45
# 97     17.00
# 119     1.05
# 217     3.15
# 180     0.30
# 63     23.50
# 255     3.00
# 44      1.25
# 227     2.55
# 274     5.30
# 51     23.00
# 235     9.10
# 265     6.50
# 223     8.25
# 117     1.10
# 289    10.11
# 293     3.25
# 141     0.60
# 287     5.75
# 246     3.75
# 62     18.75
# 211    11.75
# 187     0.25
# 91     11.25
# 121     1.05
# 248     4.00
# 203     2.95
# 270     4.10
# 252     5.40
# 259     3.90
# 197     0.16
# 215     4.50
# 173     0.40
# 40      5.85
# 282     8.25
# 69     14.25
# 26      4.15
# 61      4.50
# 125     0.90
# 101     1.70
# 95      5.85
# 234     5.50
# 257     8.50
# 291     5.40
# 85      2.50
# 57      4.75
# 231     9.25
# 136     0.65
# 108     1.20
# 273     2.25
# 49      7.75
# 225     2.70
# 170     0.40
# Name: Selling_Price, dtype: float64

# %%
ypred = regressor . predict(x_test)

# %%
ypred
# Out:
# array([-2.94515231e+00,  1.01021151e+01,  2.29951749e+00,  2.12760252e+00,
#         4.26446458e+00,  1.66589798e+01,  4.12505620e+00,  5.78842124e-01,
#         1.05195618e+01,  7.25583960e-01,  4.05881323e+00, -5.23582051e-01,
#         2.03943673e+01,  2.68408858e+00,  1.57203878e+00,  1.88263997e+00,
#         4.26902412e+00,  1.81558319e+01,  6.56372309e+00,  6.23708375e+00,
#         7.37008860e+00,  1.47315953e+00,  7.97320596e+00,  3.90334934e+00,
#         1.37149894e+00,  6.50126813e+00,  3.38608216e+00,  1.98497863e+01,
#         9.74582729e+00,  6.48398326e-03,  9.83225014e+00, -2.40758157e-01,
#         2.87466753e+00,  1.97197491e+00,  4.18877853e+00,  6.27327163e+00,
#         4.25936498e+00, -1.18213225e+00,  4.48935325e+00,  3.40677317e+00,
#         7.14724909e+00,  8.92150523e+00,  1.10731815e+01,  3.29247188e+00,
#         4.92934446e+00, -1.08390524e+00,  2.28932796e+00,  8.22758954e+00,
#         4.25449227e+00,  7.43663720e+00,  4.29407105e+00,  9.84451325e+00,
#         7.51511528e+00,  6.56440046e+00,  7.35278849e-01,  1.67849947e+00,
#         2.77168933e+00,  8.08462134e+00,  2.12168753e+00, -1.23973268e-01])

# %%
car.Selling_Price.plot()
# Out:
# <Axes: >

# %%
train_data_prediction= regressor.predict(x_train)

# %%
test_data_prediction = regressor.predict(x_train)

# %%
from sklearn import metrics
error_score = metrics.r2_score(y_train, train_data_prediction)
print('R squared error:',error_score)
# Out:
# R squared error: 0.8754757188882141

# %%
print('R squared training set :', round(regressor.score(x_test,y_test)))
# Out:
# R squared training set : 1

# %%
print('R squared test set : ',round(regressor.score(x_train,y_train)*1))
# Out:
# R squared test set :  1

# %%
regressor.coef_
# Out:
# array([ 4.24748376e-01, -4.83833583e-06,  5.32118527e-01, -3.94592631e-01,
#         2.30317731e+00,  4.83901887e-01, -1.12128601e+00, -1.67338175e+00])

# %%
plt.scatter(y_train,train_data_prediction)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual Price vs Predicted Price')
plt.show()

# %%
test_data_prediction = regressor.predict(x_test)

# %%
from sklearn import metrics
error_score = metrics.r2_score(y_test, test_data_prediction)
print('R squared error:',error_score)
# Out:
# R squared error: 0.8696747072487949

# %%
print('R squared training set : ',round(regressor.score(x_test,y_test)))
# Out:
# R squared training set :  1

# %%
print('R squared test set : ',round(regressor.score(x_train,y_train)))
# Out:
# R squared test set :  1

# %%
plt.scatter(y_test,test_data_prediction)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual Price vs Predicted Price')
plt.show()

# %%
y_pred = regressor.predict(x_test)
print(y_pred)
# Out:
# [-2.94515231e+00  1.01021151e+01  2.29951749e+00  2.12760252e+00
#   4.26446458e+00  1.66589798e+01  4.12505620e+00  5.78842124e-01
#   1.05195618e+01  7.25583960e-01  4.05881323e+00 -5.23582051e-01
#   2.03943673e+01  2.68408858e+00  1.57203878e+00  1.88263997e+00
#   4.26902412e+00  1.81558319e+01  6.56372309e+00  6.23708375e+00
#   7.37008860e+00  1.47315953e+00  7.97320596e+00  3.90334934e+00
#   1.37149894e+00  6.50126813e+00  3.38608216e+00  1.98497863e+01
#   9.74582729e+00  6.48398326e-03  9.83225014e+00 -2.40758157e-01
#   2.87466753e+00  1.97197491e+00  4.18877853e+00  6.27327163e+00
#   4.25936498e+00 -1.18213225e+00  4.48935325e+00  3.40677317e+00
#   7.14724909e+00  8.92150523e+00  1.10731815e+01  3.29247188e+00
#   4.92934446e+00 -1.08390524e+00  2.28932796e+00  8.22758954e+00
#   4.25449227e+00  7.43663720e+00  4.29407105e+00  9.84451325e+00
#   7.51511528e+00  6.56440046e+00  7.35278849e-01  1.67849947e+00
#   2.77168933e+00  8.08462134e+00  2.12168753e+00 -1.23973268e-01]

# %%
regressor.coef_
# Out:
# array([ 4.24748376e-01, -4.83833583e-06,  5.32118527e-01, -3.94592631e-01,
#         2.30317731e+00,  4.83901887e-01, -1.12128601e+00, -1.67338175e+00])

# %%
car.min()
# Out:
# Selling_Price                0.10
# Present_Price                0.32
# Driven_kms                 500.00
# Owner                        0.00
# Age of Car                   5.00
# Fuel_Type_Diesel             0.00
# Fuel_Type_Petrol             0.00
# Selling_type_Individual      0.00
# Transmission_Manual          0.00
# dtype: float64

# %%
car.max()
# Out:
# Selling_Price                  35.0
# Present_Price                  92.6
# Driven_kms                 500000.0
# Owner                           3.0
# Age of Car                     20.0
# Fuel_Type_Diesel                1.0
# Fuel_Type_Petrol                1.0
# Selling_type_Individual         1.0
# Transmission_Manual             1.0
# dtype: float64

# %%
car.mode()
# Out:
#    Selling_Price  Present_Price  Driven_kms  Owner  Age of Car  \
# 0           0.45            9.4       15000    0.0         8.0
# 1           0.60            NaN       45000    NaN         NaN
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Selling_type_Individual  \
# 0               0.0               1.0                      0.0
# 1               NaN               NaN                      NaN
#
#    Transmission_Manual
# 0                  1.0
# 1                  NaN

# %%
car.mean()
# Out:
# Selling_Price                  4.589632
# Present_Price                  7.541037
# Driven_kms                 36916.752508
# Owner                          0.043478
# Age of Car                     9.384615
# Fuel_Type_Diesel               0.193980
# Fuel_Type_Petrol               0.799331
# Selling_type_Individual        0.354515
# Transmission_Manual            0.869565
# dtype: float64

# %%
car.median()
# Out:
# Selling_Price                  3.51
# Present_Price                  6.10
# Driven_kms                 32000.00
# Owner                          0.00
# Age of Car                     9.00
# Fuel_Type_Diesel               0.00
# Fuel_Type_Petrol               1.00
# Selling_type_Individual        0.00
# Transmission_Manual            1.00
# dtype: float64
